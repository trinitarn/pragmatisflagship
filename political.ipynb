# %%
import pandas as pd
df = pd.read_excel("df.xlsx")

# %%
df
# Out:
#      Unnamed: 0           username  \
# 0             0  alvinmuhammad6222
# 1             1          kutut7262
# 2             2          kutut7262
# 3             3             tavhir
# 4             4          kutut7262
# ..          ...                ...
# 991         991          nayarisk_
# 992         992         nitavirda_
# 993         993          nayarisk_
# 994         994       annsalstarii
# 995         995          miss_ecca
#
#                                                comment  total_like  \
# 0                                             🔥🔥🔥🔥❤️😍😂           0
# 1    @alvinmuhammad6222 GANJAR PRANOWO SAJA SALAM M...           0
# 2    @alvinmuhammad6222 NEGARA ADIL, MARITIM, LESTA...           0
# 3                                      Isep isep terus           3
# 4    @tavhir GANJAR PRANOWO SAJA SALAM METAL DARI P...           0
# ..                                                 ...         ...
# 991  @nitavirda_ Seriusan emangnya bisa bantu nurun...           0
# 992  @nayarisk_ Ohh ternyata kaka juga order di @ni...           0
# 993  @anatasyafitri_ Jadi penasaran pengin cobain l...           0
# 994                                                😍😍😍           4
# 995                                             ❤️❤️❤️           9
#
#      total_reply  is_reply           reply_to  \
# 0       0.028986         0                NaN
# 1       0.000000         1  alvinmuhammad6222
# 2       0.000000         1  alvinmuhammad6222
# 3       0.028986         0                NaN
# 4       0.000000         1             tavhir
# ..           ...       ...                ...
# 991     0.000000         1          nayarisk_
# 992     0.000000         1          nayarisk_
# 993     0.000000         1          nayarisk_
# 994     0.000000         0                NaN
# 995     0.000000         0                NaN
#
#                                         parent_comment  \
# 0                                                  NaN
# 1                                             🔥🔥🔥🔥❤️😍😂
# 2                                             🔥🔥🔥🔥❤️😍😂
# 3                                                  NaN
# 4                                      Isep isep terus
# ..                                                 ...
# 991  Lihat body kak fero makin nambah ideal aja kas...
# 992  Lihat body kak fero makin nambah ideal aja kas...
# 993  Lihat body kak fero makin nambah ideal aja kas...
# 994                                                NaN
# 995                                                NaN
#
#                                          clean_comment  char_length  \
# 0                                                  NaN     0.000000
# 1    alvinmuhammad6222 ganjar pranowo saja salam me...     0.248894
# 2    alvinmuhammad6222 negara adil maritim lestari ...     0.121681
# 3                                      isep isep terus     0.016593
# 4    tavhir ganjar pranowo saja salam metal dari pd...     0.236726
# ..                                                 ...          ...
# 991  nitavirda_ seriusan emangnya bisa bantu nuruni...     0.090708
# 992  nayarisk_ ohh ternyata kaka juga order di nice...     0.121681
# 993  anatasyafitri_ jadi penasaran pengin cobain la...     0.133850
# 994                                                NaN     0.000000
# 995                                                NaN     0.000000
#
#      word_count  punct  unique_words  unique_ratio  influence_score  \
# 0      0.000000      0      0.000000      0.000000         0.002899
# 1      0.251799     12      0.238095      0.714869         0.267432
# 2      0.093525      6      0.114286      0.882352         0.204335
# 3      0.021583      0      0.019048      0.514705         0.392379
# 4      0.251799     12      0.238095      0.714869         0.264390
# ..          ...    ...           ...           ...              ...
# 991    0.086331      4      0.114286      0.950225         0.205334
# 992    0.129496      5      0.152381      0.866872         0.216827
# 993    0.122302      6      0.161905      0.972221         0.236137
# 994    0.000000      0      0.000000      0.000000         0.400000
# 995    0.000000      0      0.000000      0.000000         0.900000
#
#                                         processed_text  sentiment_score  \
# 0                                                  NaN              NaN
# 1    alvinmuhammad6222 ganjar pranowo salam metal p...              NaN
# 2    alvinmuhammad6222 negara adil maritim lestari ...              NaN
# 3                                            isep isep              NaN
# 4    tavhir ganjar pranowo salam metal pdi perjuang...              NaN
# ..                                                 ...              ...
# 991  nitavirda_ seriusan emangnya bantu nurunin bb ...              NaN
# 992  nayarisk_ ohh kaka order niceslim_ kak aja kem...              NaN
# 993  anatasyafitri_ penasaran pengin cobain lansung...              NaN
# 994                                                NaN              NaN
# 995                                                NaN              NaN
#
#      predicted_score
# 0           0.970000
# 1           0.256667
# 2           0.363333
# 3           0.863333
# 4           0.256667
# ..               ...
# 991         0.393333
# 992         0.363333
# 993         0.330000
# 994         0.986667
# 995         0.986667
#
# [996 rows x 18 columns]

# %%
top_reply = df.sort_values(
    by="total_reply",
    ascending=False
).head(50)

# %%
top_reply
# Out:
#       Unnamed: 0             username  \
# 1927        1927              ap16___
# 1212        1212     visit_kalsel_new
# 1421        1421    muhamadrizki25063
# 1080        1080            andri_j77
# 576          576             romaucha
# 721          721     eliandri_bahtiar
# 2297        2297              prczalt
# 1777        1777          addy_900444
# 827          827          andri_frnnd
# 1008        1008         muh_nurharis
# 868          868          reyyhan__11
# 1892        1892         mey.korompis
# 1906        1906            cesaryuga
# 1151        1151            hellobg__
# 1678        1678           rwehantouw
# 947          947         anry.sumarna
# 1914        1914        hilya.mafaz99
# 371          371             jimi70tv
# 1877        1877          salenduyuni
# 2293        2293       vivi_sumampouw
# 515          515       kholisnawawi06
# 379          379  santrialhusnamayong
# 1795        1795         annetteldewi
# 305          305           donoganeff
# 787          787            ofcmahesa
# 1757        1757             cc_siinn
# 1923        1923           itscharmes
# 538          538            meizaamsa
# 2319        2319         nurhaeni_026
# 118          118          ghofur.mhmd
# 1553        1553          sakariaiyas
# 256          256      abdilahmutakhin
# 362          362          rahmatalwie
# 424          424          this.is.mus
# 183          183         lazirhaf.agr
# 1809        1809          nndalakaeng
# 1872        1872   vicky_alycia_fitri
# 513          513            14__putra
# 330          330          ___faw26___
# 972          972          misteriuz24
# 223          223             eiskan01
# 1029        1029             doeabduh
# 1169        1169            dindareyn
# 2290        2290  mishaelsandrina_mse
# 1044        1044           aku_nanag3
# 20            20          bintiyahmin
# 21            21         nursatrianty
# 22            22  priaberistrimasjuli
# 23            23      princesbella_93
# 24            24            _rukoyah_
#
#                                                 comment  total_like  \
# 1927  ada kepentingan pribadi apaan kira” dukung yg ...         295
# 1212  Para artis dan selebgram dukung 02 utk kelanca...        1079
# 1421              Soryy yehhh #01MENANG UNTUK PERUBAHAN         845
# 1080                    Pendukung sebelah makin panas😂😂         398
# 576   Pendukung 01 kalo ga nyaci gak tenang,pdahal d...          12
# 721   Padahal masih user MELON ELPIJI, tapi malah du...         357
# 2297   Absen yang All pak Bowo dan mas Gibran--------->        2077
# 1777         Tetap NOMOR 1 ☝☝☝☝☝☝☝☝☝☝☝☝☝☝☝☝❤❤❤❤❤❤😎😎😎😎😎😎         131
# 1906     0.018970         0      NaN            NaN
# 1151     0.016260         0      NaN            NaN
# 1678     0.013550         0      NaN            NaN
# 947      0.013550         0      NaN            NaN
# 1914     0.010840         0      NaN            NaN
# 371      0.008130         0      NaN            NaN
# 1877     0.008130         0      NaN            NaN
# 2293     0.005420         0      NaN            NaN
# 515      0.005420         0      NaN            NaN
# 379      0.005420         0      NaN            NaN
# 1795     0.005420         0      NaN            NaN
# 305      0.005420         0      NaN            NaN
# 787      0.005420         0      NaN            NaN
# 1757     0.005420         0      NaN            NaN
# 1923     0.005420         0      NaN            NaN
# 538      0.005420         0      NaN            NaN
# 2319     0.005420         0      NaN            NaN
# 118      0.002710         0      NaN            NaN
# 1553     0.002710         0      NaN            NaN
# 256      0.002710         0      NaN            NaN
# 362      0.002710         0      NaN            NaN
# 424      0.002710         0      NaN            NaN
# 183      0.002710         0      NaN            NaN
# 1809     0.002710         0      NaN            NaN
# 1872     0.002710         0      NaN            NaN
# 513      0.002710         0      NaN            NaN
# 330      0.002710         0      NaN            NaN
# 972      0.002710         0      NaN            NaN
# 223      0.002710         0      NaN            NaN
# 1029     0.002710         0      NaN            NaN
# 1169     0.002710         0      NaN            NaN
# 2290     0.002710         0      NaN            NaN
# 1044     0.002710         0      NaN            NaN
# 20       0.000000         0      NaN            NaN
# 21       0.000000         0      NaN            NaN
# 22       0.000000         0      NaN            NaN
# 23       0.000000         0      NaN            NaN
# 24       0.000000         0      NaN            NaN
#
#                                           clean_comment  char_length  \
# 1927  ada kepentingan pribadi apaan kira dukung yg b...     0.038504
# 1212  para artis dan selebgram dukung 02 utk kelanca...     0.118304
# 1421               soryy yehhh 01menang untuk perubahan     0.020089
# 1080                      pendukung sebelah makin panas     0.016183
# 576   pendukung 01 kalo ga nyaci gak tenangpdahal di...     0.053571
# 721   padahal masih user melon elpiji tapi malah duk...     0.037388
# 2297             absen yang all pak bowo dan mas gibran     0.021205
# 1777                                     tetap nomor 1      0.007812
# 827   rasulullah saw telah menegaskan kepada kita \n...     0.588170
# 1008                                            01 anis     0.003906
# 868                                         kok sepi ya     0.006138
# 1892                                                NaN     0.000000
# 1906                      bngga dg artis muda indonesi      0.016183
# 1151                   sehatsehat para pendukung bapak      0.017857
# 1678  dtuturoong baru langowan ini  tu koni blum dg ...     0.036830
# 947   saya 2 kali pilih bapak skrg waktunya istiraha...     0.031250
# 1914  disini ada yg sudah pernah program perawatan p...     0.047991
# 371                      tombol all in prabowo gibran       0.016741
# 1877                      all in prabowo02 pasti menang     0.016183
# 2293                                    manado ini kang     0.008371
# 515                         tetap nomor 1 anis muhaimin     0.015067
# 379   apa saya salah pandang\nkalo mbah wowo jalan p...     0.083147
# 1795  menado sebiru langit yang indah dengan bapak p...     0.032924
# 305   perasaan ini mulu yg diposting apa yg lain sep...     0.028460
# 787   kasian pndkung 01 promosiin cpres nya di lapak 02     0.027344
# 1757  awasss ngoni bilng edit ehh tamo kuti di mulu ...     0.030134
# 1923                     di manado inisalam gemooyy pak     0.016741
# 1044                                                 01             -1.0
# 20                               rame n glowing nomer 1              NaN
# 21    orang ganteng ngumpul gimana emak² ga oleng co...              NaN
# 22                                            all in 02              NaN
# 23                          pokoe prabowo gibran menang              NaN
# 24    pengen bapa prabowo sakit kaki penyakit kasian...              NaN
#
#       predicted_score
# 1927        -0.180000
# 1212        -0.733333
# 1421        -0.373333
# 1080         0.480000
# 576         -0.760000
# 721          0.706667
# 2297         0.646667
# 1777         0.446667
# 827         -0.056667
# 1008        -0.650000
# 868          0.240000
# 1892         0.466667
# 1906         1.000000
# 1151         0.383333
# 1678         0.370000
# 947          0.683333
# 1914        -0.436667
# 371          0.986667
# 1877         0.866667
# 2293         0.293333
# 515         -0.400000
# 379         -0.593333
# 1795         0.963333
# 305          0.133333
# 787          0.063333
# 1757         0.370000
# 1923         0.953333
# 538         -0.796667
# 2319         0.266667
# 118          0.330000
# 1553         0.746667
# 256          0.406667
# 362          0.406667
# 424          0.406667
# 183          0.446667
# 1809         0.503333
# 1872         1.000000
# 513         -0.693333
# 330          0.110000
# 972          0.640000
# 223         -0.543333
# 1029        -0.366667
# 1169         0.986667
# 2290         0.246667
# 1044        -0.800000
# 20           0.410000
# 21          -0.503333
# 22           0.393333
# 23           0.296667
# 24          -0.503333

# %%
engaging = df.drop(
    df[
        (df['total_reply'] == 0) & 
        (df['is_reply'] == 0)
    ].index
)
engaging.to_excel("engaging.xlsx")

# %%
engaging
# Out:
#       Unnamed: 0      username  \
# 118          118   ghofur.mhmd
# 119          119    efriana.a_
# 183          183  lazirhaf.agr
# 184          184     hildamrgt
# 223          223      eiskan01
# ...          ...           ...
# 2316        2316   nikosptra41
# 2317        2317   kiky_260981
# 2319        2319  nurhaeni_026
# 2320        2320     sumi.sudi
# 2321        2321  nurhaeni_026
#
#                                                 comment  total_like  \
# 118                                        JOGED MULU 🤣           1
# 119   Daripad  sholawatan  sambil ghibah .mending  j...           0
# 183            Bismillah Prabowo Gibran presidenya amin           0
# 184                             @lazirhaf.agr All In ✌✌           0
# 223   Udah pak saya kasihan melihatmu,sebaiknya isti...           2
# ...                                                 ...         ...
# 2316                   @sahrulmahesa22 luu ngentot bang           0
# 2317                                 @prczalt 🤢🤢🤢🤢🤮🤮🤮🤮🤮           0
# 2319                               Semangat bang 02 🔥🔥🔥          13
# 2320                      @nurhaeni_026 Bismillah 02 🤲🤲           2
# 2321                           @sumi.sudi yes jg Bun 02           2
#
#       total_reply  is_reply      reply_to  \
# 118       0.00271         0           NaN
# 119       0.00000         1   ghofur.mhmd
# 183       0.00271         0           NaN
# 184       0.00000         1  lazirhaf.agr
# 223       0.00271         0           NaN
# ...           ...       ...           ...
# 2316      0.00000         1       prczalt
# 2317      0.00000         1       prczalt
# 2319      0.00542         0           NaN
# 2320      0.00000         1  nurhaeni_026
# 2321      0.00000         1  nurhaeni_026
#
#                                         parent_comment  \
# 118                                                NaN
# 119                                       JOGED MULU 🤣
# 183                                                NaN
# 184           Bismillah Prabowo Gibran presidenya amin
# 223                                                NaN
# ...                                                ...
# 2321                           @sumi.sudi yes jg Bun 02           2
# 2322  📌 14 0️⃣2️⃣ 2024 Oke Gas Dukungan kita kepada ...          51
# 2323               Pokoknya dukung prabowo gibran gemoy          36
#
#       total_reply  is_reply      reply_to        parent_comment  \
# 0         0.00000         0           NaN                   NaN
# 1         0.00000         0           NaN                   NaN
# 2         0.00000         0           NaN                   NaN
# 3         0.00000         0           NaN                   NaN
# 4         0.00000         0           NaN                   NaN
# ...           ...       ...           ...                   ...
# 2319      0.00542         0           NaN                   NaN
# 2320      0.00000         1  nurhaeni_026  Semangat bang 02 🔥🔥🔥
# 2321      0.00000         1  nurhaeni_026  Semangat bang 02 🔥🔥🔥
# 2322      0.00000         0           NaN                   NaN
# 2323      0.00000         0           NaN                   NaN
#
#                                           clean_comment  char_length  \
# 0                                      ayang gue cakep²     0.008929
# 1                                 prabowo gibran menang     0.011719
# 2                                                   NaN     0.000000
# 3                               nomor 2 ok gass prabowo     0.012835
# 4                                           masha allah     0.006138
# ...                                                 ...          ...
# 2319                                  semangat bang 02      0.009487
# 2320                         nurhaeni_026 bismillah 02      0.014509
# 2321                             sumisudi yes jg bun 02     0.012277
# 2322   14 02 2024 oke gas dukungan kita kepada prabo...     0.034040
# 2323               pokoknya dukung prabowo gibran gemoy     0.020089
#
#       word_count  punct  unique_words  unique_ratio  influence_score  \
# 0       0.010870      0       0.01875      0.770833         0.123781
# 1       0.010870      0       0.01875      0.770833         0.124478
# 2       0.000000      0       0.00000      0.000000         0.000000
# 3       0.018116      1       0.03125      0.856481         0.241554
# 4       0.007246      0       0.01250      0.685184         0.108262
# ...          ...    ...           ...           ...              ...
# 2319    0.010870      0       0.01875      0.770833         1.424462
# 2320    0.010870      2       0.01875      0.770833         0.325176
# 2321    0.018116      2       0.03125      0.856481         0.341414
# 2322    0.039855     16       0.06875      0.942129         5.271550
# 2323    0.018116      0       0.03125      0.856481         3.743368
#
#                                       processed_text  sentiment_score  \
# 0                                   ayang gue cakep²              NaN
# 1                              prabowo gibran menang              NaN
# 2                                                NaN              NaN
# 3                            nomor 2 ok gass prabowo              NaN
# 4                                        masha allah              NaN
# ...                                              ...              ...
# 2319                                semangat bang 02              NaN
# 2320                       nurhaeni_026 bismillah 02              NaN
# 2321                          sumisudi yes jg bun 02              NaN
# 2322  14 02 2024 oke gas dukungan prabowogibran ri 1              1.0
# 2323            pokoknya dukung prabowo gibran gemoy              1.0
#
#       predicted_score  mention_opponent
# 0            0.933333                 0
# 1            1.000000                 0
# 2            1.000000                 0
# 3            0.960000                 0
# 4            0.993333                 0
# ...               ...               ...
# 2319         0.986667                 0
# 2320         0.986667                 0
# 2321         0.986667                 0
# 2322         0.860000                 0
# 2323         0.873333                 0
#
# [2324 rows x 20 columns]

# %%
df['positif or negatif'] = df['predicted_score'].apply(
    lambda x: "1" if x > 0 else "0"
)

# %%
df
# Out:
#       Unnamed: 0.1  Unnamed: 
rows x 21 columns]

# %%
import matplotlib.pyplot as plt

# Hitung jumlah 0 dan 1
sentiment_counts = (
    df["positif or negatif"]
    .dropna()                 # buang NaN kalau ada
    .value_counts()
    .sort_index()             # urutkan 0 dulu baru 1
)

print(sentiment_counts)  # cek dulu isinya

# Labels
labels = ["Negatif", "Positif"]

# Warna
colors = ["#F44336", "#4CAF50"]

# Pie chart
plt.figure()

plt.pie(
    sentiment_counts,
    labels=labels,
    autopct="%1.1f%%",
    startangle=90,
    colors=colors
)

plt.title("Sentiment Distribution (0 vs 1)")
plt.axis("equal")

plt.show()
# Out:
# positif or negatif
# 0     299
# 1    2025
# Name: count, dtype: int64

# %%
df
# Out:
#               username                                            comment  \
# 0    alvinmuhammad6222                                           🔥🔥🔥🔥❤️😍😂
# 1            kutut7262  @alvinmuhammad6222 GANJAR PRANOWO SAJA SALAM M...
# 2            kutut7262  @alvinmuhammad6222 NEGARA ADIL, MARITIM, LESTA...
# 3               tavhir                                    Isep isep terus
# 4            kutut7262  @tavhir GANJAR PRANOWO SAJA SALAM METAL DARI P...
# ..                 ...                                                ...
# 991          nayarisk_  @nitavirda_ Seriusan emangnya bisa bantu nurun...
# 992         nitavirda_  @nayarisk_ Ohh ternyata kaka juga order di @ni...
# 993          nayarisk_  @anatasyafitri_ Jadi penasaran pengin cobain l...
# 994       annsalstarii                                                😍😍😍
# 995          miss_ecca                                             ❤️❤️❤️
#
#      total_like  total_reply  is_reply           reply_to  \
# 0             0     0.028986         0                NaN
# 1             0     0.000000         1  alvinmuhammad6222
# 2             0     0.000000         1  alvinmuhammad6222
# 3             3     0.028986         0                NaN
# 4             0     0.000000         1             tavhir
# ..          ...          ...       ...                ...
# 991           0     0.000000         1          nayarisk_
# 992           0     0.000000         1          nayarisk_
# 993           0     0.000000         1          nayarisk_
# 994           4     0.000000         0                NaN
# 995           9     0.000000         0                NaN
#
#                                         parent_comment  \
# 0                                                  NaN
# 1                                             🔥🔥🔥🔥❤️😍😂
# 2                                             🔥🔥🔥🔥❤️😍😂
# 3                                                  NaN
# 4                                      Isep isep terus
# ..                                                 ...
# 991  Lihat body kak fero makin nambah ideal aja kas...
# 992  Lihat body kak fero makin nambah ideal aja kas...
# 993  Lihat body kak fero makin nambah ideal aja kas...
# 994                                                NaN
# 995                                                NaN
#
#                                          clean_comment  char_length  \
# 0                                                  NaN     0.000000
# 1    alvinmuhammad6222 ganjar pranowo saja salam me...     0.248894
# 2    alvinmuhammad6222 negara adil maritim lestari ...     0.121681
# 3                                      isep isep terus     0.016593
# 4    tavhir ganjar pranowo saja salam metal dari pd...     0.236726
# ..                                                 ...          ...
# 991  nitavirda_ seriusan emangnya bisa bantu nuruni...     0.090708
# 992  nayarisk_ ohh ternyata kaka juga order di nice...     0.121681
# 993  anatasyafitri_ jadi penasaran pengin cobain la...     0.133850
# 994                                                NaN     0.000000
# 995                                                NaN     0.000000
#
#      word_count  punct  unique_words  unique_ratio  influence_score  \
# 0      0.000000      0      0.000000      0.000000         0.002899
# 1      0.251799     12      0.238095      0.714869         0.267432
# 2      0.093525      6      0.114286      0.882352         0.204335
# 3      0.021583      0      0.019048      0.514705         0.392379
# 4      0.251799     12      0.238095      0.714869         0.264390
# ..          ...    ...           ...           ...              ...
# 991    0.086331      4      0.114286      0.950225         0.205334
# 992    0.129496      5      0.152381      0.866872         0.216827
# 993    0.122302      6      0.161905      0.972221         0.236137
# 994    0.000000      0      0.000000      0.000000         0.400000
# 995    0.000000      0      0.000000      0.000000         0.900000
#
#                                         processed_text  sentiment_score  \
# 0                                                  NaN              NaN
# 1    alvinmuhammad6222 ganjar pranowo salam metal p...              NaN
# 2    alvinmuhammad6222 negara adil maritim lestari ...              NaN
# 3                                            isep isep              NaN
# 4    tavhir ganjar pranowo salam metal pdi perjuang...              NaN
# ..                                                 ...              ...
# 991  nitavirda_ seriusan emangnya bantu nurunin bb ...              NaN
# 992  nayarisk_ ohh kaka order niceslim_ kak aja kem...              NaN
# 993  anatasyafitri_ penasaran pengin cobain lansung...              NaN
# 994                                                NaN              NaN
# 995                                                NaN              NaN
#
#      predicted_score  mention_opponent  positif or negatif
# 0           0.970000                 0                   1
# 1          -0.463333                 1                   0
# 2          -0.793333                 1                   0
# 3           0.820000                 0                   1
# 4          -0.463333                 1                   0
# ..               ...               ...                 ...
# 991         0.790000                 0                   1
# 992         0.800000                 0                   1
# 993         0.153333                 0                   1
# 994         0.970000                 0                   1
# 995         0.970000                 0                   1
#
# [996 rows x 19 columns]

# %%
# so i have a vision of making a visualization in which I make the predictive score as the x axis, so it has to be from -1 to 1, and then the y ordinat is the frequency of reply, so we want to see which sentiment score got better engagement
import pandas as pd
import matplotlib.pyplot as plt

plt.figure()

plt.scatter(
    df["predicted_score"],
    df["total_reply"]
)

plt.title("Sentiment Score vs Reply Engagement")

plt.xlabel("Sentiment Score (-1 to 1)")
plt.ylabel("Reply Count")

plt.show()

# %%
import numpy as np

# Bikin interval sentiment
bins = np.linspace(-1, 1, 21)

df["sentiment_bin"] = pd.cut(
    df["predicted_score"],
    bins
)
reply_avg = df.groupby(
    "sentiment_bin"
)["total_reply"].mean()
plt.figure()

reply_avg.plot(
    kind="bar"
)

plt.title("Average Replies by Sentiment Score")

plt.xlabel("Sentiment Score Range")
plt.ylabel("Average Reply Count")

plt.xticks(rotation=90)

plt.show()
# Out:
# C:\Users\nitar\AppData\Local\Temp\ipykernel_4860\1926992007.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   reply_avg = df.groupby(

# %%
# what are the neutral ones?
# adya_llss merasa pilihan dia yang paling tepat lu mau pilih apa itu hakmu ga usah sok jadi paling benar kosong emang
# aku semakin yakin dukung anis imin
# 1 the best man in the world pak anies baswedan jadi presiden guys prestasi membangun jakarta sukses mari berfikir waras dan berpikir kritis memilih pemimpin salam anti plonga plongo  2 urus keluarga gagalbeli pesawat jet bekas korupsi pt tmi 1760 t food estate 1088 t gagal belom jadi presiden program program udah pada gagal  3 ganjar bokep mulu fakta jateng masih miskin fakta korupsi ektp fakta  wadas gga jelas fakta bodoh bodoh cebong pdi gudang nya korupsi juga fakta apa yang kalian banggakan
# bingun sama artis artis mereka padahal rata rata berpendidikan tinggi tapi apa buta mata buta hati banyak dukung paslon yang punya wakil jalur mk dan curang 
# muhammaddedieee dukung jadi rakyat
# dapet apa sih udh gak laku ya sinetronnya
# sam_rajiemin54 komisaris apa tu bang

# they don't attack another buzzer, they attack real people with real opinions

# %%
import numpy as np

plt.figure()

plt.scatter(
    df["predicted_score"],
    df["total_reply"],
    alpha=0.3
)

# Add trend line
z = np.polyfit(
    df["predicted_score"],
    df["total_reply"],
    1
)

p = np.poly1d(z)

plt.plot(
    df["predicted_score"],
    p(df["predicted_score"])
)

plt.title("Sentiment Score vs Reply Engagement")

plt.xlabel("Sentiment Score (-1 to 1)")
plt.ylabel("Reply Count")

plt.show()

# %%
# when mentioning opponents, are the tendencies positive or negative?
# stacked graph to determine whether the sentiment of comments that mentioning opponents names are
# positif or negatif

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cross-tabulation
cross = pd.crosstab(
    df["mention_opponent"],
    df["positif or negatif"]
)

# Rename columns (biar jelas)
cross.columns = ["Negative", "Positive"]

# Rename index
cross.index = ["No Opponent Mention", "Opponent Mention"]

# Plot stacked bar
cross.plot(
    kind="bar",
    stacked=True
)

plt.title("Sentiment of Comments Mentioning Opponents")

plt.xlabel("Opponent Mention")
plt.ylabel("Number of Comments")

plt.xticks(rotation=0)

plt.legend(title="Sentiment")

plt.show()

# %%
top_comments = df.sort_values(
    by="total_reply",
    ascending=False
)[[
    "clean_comment",
    "mention_opponent",
    "total_reply"
]].head(15)

top_comments
# Out:
#                                           clean_comment  mention_opponent  \
# 1927  ada kepentingan pribadi apaan kira dukung yg b...                 0
# 1212  para artis dan selebgram dukung 02 utk kelanca...                 0
# 1421               soryy yehhh 01menang untuk perubahan                 0
# 1080                      pendukung sebelah makin panas                 0
# 576   pendukung 01 kalo ga nyaci gak tenangpdahal di...                 0
# 721   padahal masih user melon elpiji tapi malah duk...                 0
# 2297             absen yang all pak bowo dan mas gibran                 0
# 1777                                     tetap nomor 1                  0
# 827   rasulullah saw telah menegaskan kepada kita \n...                 0
# 1008                                            01 anis                 1
# 868                                         kok sepi ya                 0
# 1892                                                NaN                 0
# 1906                      bngga dg artis muda indonesi                  0
# 1151                   sehatsehat para pendukung bapak                  0
# 1678  dtuturoong baru langowan ini  tu koni blum dg ...                 0
#
#       total_reply
# 1927     1.000000
# 1212     0.506775
# 1421     0.178862
# 1080     0.178862
# 576      0.094851
# 721      0.094851
# 2297     0.056911
# 1777     0.048780
# 827      0.043360
# 1008     0.043360
# 868      0.035230
# 1892     0.024390
# 1906     0.018970
# 1151     0.016260
# 1678     0.013550

# %%
import sys
# !{sys.executable} -m pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\nitar\appdata\local\programs\python\python310\lib\site-packages (1.9.6)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\nitar\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (2.1.1)
# Requirement already satisfied: pillow in c:\users\nitar\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in c:\users\nitar\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nitar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\nitar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nitar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (4.54.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nitar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\nitar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nitar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nitar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\nitar\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
import wordcloud
print("Wordcloud installed successfully!")
# Out:
# Wordcloud installed successfully!

# %%
# !pip install wordcloud
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# =========================
# STOPWORDS (kata yang mau dihapus)
# =========================

stopwords = {
    "dan","yang","di","ke","dari",
    "ini","itu","aja","nya",
    "untuk","dengan","karena",
    "atau","pada","jadi",
    "adalah","seperti","tidak",
    "ya","ga","gak","nya",
    "the","is","are"
}

# =========================
# POSITIVE WORDCLOUD
# =========================

positive_text = " ".join(
    df[df["predicted_score"] > 0]["clean_comment"].astype(str)
)

positive_wc = WordCloud(
    width=800,
    height=400,
    background_color="white",
    stopwords=stopwords   # ← DITARO DI SINI
).generate(positive_text)

# =========================
# NEGATIVE WORDCLOUD
# =========================

negative_text = " ".join(
    df[df["predicted_score"] < 0]["clean_comment"].astype(str)
)

negative_wc = WordCloud(
    width=800,
    height=400,
    background_color="white",
    stopwords=stopwords   # ← DITARO DI SINI JUGA
).generate(negative_text)

# =========================
# SHOW BOTH
# =========================

plt.figure(figsize=(12,6))

# Positive
plt.subplot(1,2,1)
plt.imshow(positive_wc)
plt.axis("off")
plt.title("Positive WordCloud")

# Negative
plt.subplot(1,2,2)
plt.imshow(negative_wc)
plt.axis("off")
plt.title("Negative WordCloud")

plt.show()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wordcloud in C:\Users\nitar\AppData\Roaming\Python\Python314\site-packages (1.9.6)
# Requirement already satisfied: numpy>=1.19.3 in C:\Users\nitar\AppData\Roaming\Python\Python314\site-packages (from wordcloud) (2.4.4)
# Requirement already satisfied: pillow in C:\Users\nitar\AppData\Roaming\Python\Python314\site-packages (from wordcloud) (12.2.0)
# Requirement already satisfied: matplotlib in C:\Users\nitar\AppData\Roaming\Python\Python314\site-packages (from wordcloud) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\nitar\AppData\Roaming\Python\Python314\site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\nitar\AppData\Roaming\Python\Python314\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\nitar\AppData\Roaming\Python\Python314\site-packages (from matplotlib->wordcloud) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\nitar\AppData\Roaming\Python\Python314\site-packages (from matplotlib->wordcloud) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\nitar\AppData\Roaming\Python\Python314\site-packages (from matplotlib->wordcloud) (26.1)
# Requirement already satisfied: pyparsing>=3 in C:\Users\nitar\AppData\Roaming\Python\Python314\site-packages (from matplotlib->wordcloud) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\nitar\AppData\Roaming\Python\Python314\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\nitar\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
from wordcloud import WordCloud
import pandas as pd
import matplotlib.pyplot as plt

# Load data
df = pd.read_excel("opponent.xlsx")

# =========================
# STOPWORDS
# =========================

stopwords = {
    "dan","yang","di","ke","dari",
    "ini","itu","aja","nya",
    "untuk","dengan","karena",
    "atau","pada","jadi",
    "adalah","seperti","tidak",
    "ya","ga","gak",
    "yg","dr","rt",
    "nih","dong","sih"
}

# Optional — hapus nama kandidat kalau terlalu dominan
stopwords.update({
    "anis",
    "ganjar",
    "prabowo"
})

# =========================
# FILTER TEXT
# =========================

text_o1_pos = " ".join(
    df[
        (df["mention_opponent"] == 1) &
        (df["predicted_score"] > 0)
    ]["clean_comment"].astype(str)
)

text_o1_neg = " ".join(
    df[
        (df["mention_opponent"] == 1) &
        (df["predicted_score"] < 0)
    ]["clean_comment"].astype(str)
)

text_o0_pos = " ".join(
    df[
        (df["mention_opponent"] == 0) &
        (df["predicted_score"] > 0)
    ]["clean_comment"].astype(str)
)

text_o0_neg = " ".join(
    df[
        (df["mention_opponent"] == 0) &
        (df["predicted_score"] < 0)
    ]["clean_comment"].astype(str)
)

# =========================
# PLOT 4 WORDCLOUD
# =========================

plt.figure(figsize=(14,10))

def make_wc(text, position, title):
    if text.strip():
        wc = WordCloud(
            width=800,
            height=400,
            background_color="white",
            stopwords=stopwords
        ).generate(text)

        plt.subplot(2,2,position)
        plt.imshow(wc)
        plt.axis("off")
        plt.title(title)

# Row 1 → opponent = 1
make_wc(text_o1_pos, 1, "Opponent = 1 | Positive")
make_wc(text_o1_neg, 2, "Opponent = 1 | Negative")

# Row 2 → opponent = 0
make_wc(text_o0_pos, 3, "Opponent = 0 | Positive")
make_wc(text_o0_neg, 4, "Opponent = 0 | Negative")

plt.tight_layout()
plt.show()
